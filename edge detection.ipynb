# %%
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
# file name
global_path = '.\FiguresStacked4x4 x100'
for filename in os.listdir(global_path):
    if filename.endswith('png'):
        path = os.path.join(global_path,filename)
        img = cv2.imread(path)
        # Convert to graycsale
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # Blur the image for better edge detection
        img_blur = cv2.GaussianBlur(img_gray, (3,3), 0)
        # Canny Edge Detection
        edges = cv2.Canny(image=img_blur, threshold1=100, threshold2=200)
        # Display Canny Edge Detection Image:
        plt.figure(figsize = (15,15))
        plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
        plt.title('Original'), plt.xticks([]), plt.yticks([])
        plt.subplot(2,2,2),plt.imshow(edges,cmap = 'gray')
        plt.title('Canny'), plt.xticks([]), plt.yticks([])
        directory = '.\After_processing'
        save_path = os.path.join(directory,filename)
        isWritten  = cv2.imwrite(save_path, edges)
        if isWritten:
            print('Image is successfully saved as file.')
# Out:
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# Image is successfully saved as file.
# ...
